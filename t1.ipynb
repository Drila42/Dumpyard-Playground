# %% [markdown]
# <a href="https://colab.research.google.com/github/Drila42/trial-1/blob/master/t1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
a=pd.read_excel("https://www.idbimutual.co.in/Pdf/IDBI%20MF%20Monthly_Portfolio_Report%20November%202019-23-December-2019-540402693.xls")

# %%
a
# Out:
#           Index         Unnamed: 1                              Unnamed: 2
# 0           NaN                NaN                                     NaN
# 1   Scheme Code  Scheme Short code                             Scheme Name
# 2          ID01               ID01                   IDBI Nifty Index Fund
# 3          ID02               ID02                        IDBI Liquid Fund
# 4          ID03               ID03              IDBI Ultra Short Term Fund
# 5          ID04               ID04            IDBI Nifty Junior Index Fund
# 6          ID05               ID05                IDBI Equity Savings Fund
# 7          ID06               ID06               IDBI Short Term Bond Fund
# 8          ID07               ID07                      IDBI Gold ETF Fund
# 9          ID08               ID08                  IDBI Dynamic Bond Fund
# 10         ID09               ID09          IDBI India Top 100 Equity Fund
# ...

# %%
a.columns=a.iloc[0]
a=a[1:]

# %%
a
# Out:
# 1  Scheme Code Scheme Short code                             Scheme Name
# 2         ID01              ID01                   IDBI Nifty Index Fund
# 3         ID02              ID02                        IDBI Liquid Fund
# 4         ID03              ID03              IDBI Ultra Short Term Fund
# 5         ID04              ID04            IDBI Nifty Junior Index Fund
# 6         ID05              ID05                IDBI Equity Savings Fund
# 7         ID06              ID06               IDBI Short Term Bond Fund
# 8         ID07              ID07                      IDBI Gold ETF Fund
# 9         ID08              ID08                  IDBI Dynamic Bond Fund
# 10        ID09              ID09          IDBI India Top 100 Equity Fund
# 11        ID10              ID10                          IDBI Gold Fund
# 12        ID11              ID11                          IDBI Gilt Fund
# 13        ID12              ID12              IDBI Equity Advantage Fund
# ...
